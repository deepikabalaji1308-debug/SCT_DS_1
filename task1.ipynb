# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load the dataset
df=pd.read_csv("/content/population_data.csv")

# %%
#check the data
print(df.head())
print(df.info())
# Out:
#    Person_ID  Age  Gender
# 0          1   18    Male
# 1          2   55  Female
# 2          3   20    Male
# 3          4   21  Female
# 4          5   22    Male
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Person_ID  100 non-null    int64
#  1   Age        100 non-null    int64
#  2   Gender     100 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 2.5+ KB
# None

# %%
#create a histogram for age
plt.figure(figsize=(8,5))
plt.hist(df["Age"],bins=10,edgecolor="black")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
#create a bar chart for gender
gender=df["Gender"].value_counts()
plt.figure(figsize=(6,4))
plt.bar(gender.index,gender.values)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Conclusion:
#
# *   The age didstribution shows that the most individuals are between 18 and 25 years old,with fewer people in the older age groups.
# *   The gender distribution is nearly balanced, with a slightly higher number of female records than male records.
